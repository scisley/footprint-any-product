# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env.local file
env_path = '../../.env.local'
load_dotenv(dotenv_path=env_path)

# Update with your name to group your own traces
os.environ['LANGCHAIN_PROJECT'] = 'steve-fap-sandbox'

# %%
# Firecrawl
from firecrawl import FirecrawlApp

app = FirecrawlApp(api_key=os.environ["FIRECRAWL_API_KEY"])

url = "https://www.amazon.in/Minimalist-Niacinamide-Blemishes-Balancing-Clarifying/dp/B08F9MF314"

# Scrape a website:
scrape_result = app.scrape_url(url)
print(scrape_result)
# Out:
# url=None markdown='[iframe](javascript:void(false))[iframe](javascript:void(false))[iframe](javascript:void(false))\n\n![](https://fls-eu.amazon.in/1/batch/1/OP/A21TJRUUN4KGV:259-1171195-0652911:PMW5DTT8S1CKMYGEY757$uedata=s:%2Frd%2Fuedata%3Fstaticb%26id%3DPMW5DTT8S1CKMYGEY757:0)![](https://m.media-amazon.com/images/G/31/gno/sprites/nav-sprite-global-1x-reorg-privacy._CB546381437_.png)\nShortcuts menu\nMinimalist Oil Control & Anti-Acne 10% Niacinamide Face Serum with Zinc \\| Skin Clarifying,Blemishes & Pore Care for All Skin Types \\| 30ml (Pack of 1) : Amazon.in: Beauty\n\n- [Beauty](https://www.amazon.in/beauty/b/ref=dp_bc_1?ie=UTF8&node=1355016031)\n- ›\n- [Skin Care](https://www.amazon.in/Skin-Care/b/ref=dp_bc_2?ie=UTF8&node=1374407031)\n- ›\n- [Face](https://www.amazon.in/Face/b/ref=dp_bc_3?ie=UTF8&node=1374414031)\n- ›\n- [Creams & Moisturisers](https://www.amazon.in/Creams-and-Moisturizers/b/ref=dp_bc_4?ie=UTF8&node=9530421031)\n- ›\n- [Serums](https://www.amazon.in/b/ref=dp
# ...
